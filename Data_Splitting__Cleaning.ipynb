# %% [markdown]
# <a href="https://colab.research.google.com/github/Akalbir17/Disaster_Detection/blob/main/Data_Splitting__Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The code wriiten in this file is to view, split and clean the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Unzipping the File

# %%
# !unzip "/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD).zip" -d "/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_damage_sea/06_04_1518.png
#   inflating: /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_damage_sea/06_04_1519.png
#   inflating: /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_damage_sea/06_04_1520.png
#   inflating: /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_damage_sea/06_04_1521.png
#   inflating: /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_damage_sea/06_04_1522.png
#   inflating: /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_damage_sea/06_04_1523.png
# ...

# %% [markdown]
# Getting the number of Images Present in each sub-directory

# %%
import os
import random
import pandas as pd
import numpy as np
from shutil import copyfile

data_dir='/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)'
print(len(os.listdir(data_dir+'/DamagedInfrastructure/')))
print(len(os.listdir(data_dir+'/Drought/')))
print(len(os.listdir(data_dir+'/Earthquake/')))
print(len(os.listdir(data_dir+'/Human_Damage/')))
print(len(os.listdir(data_dir+'/Land_Slide/')))
print(len(os.listdir(data_dir+'/Non_Damage_Buildings_Street/')))
print(len(os.listdir(data_dir+'/Non_Damage_Wildlife_Forest/')))
print(len(os.listdir(data_dir+'/Urban_Fire/')))
print(len(os.listdir(data_dir+'/Water_Disaster/')))
print(len(os.listdir(data_dir+'/Wild_Fire/')))
print(len(os.listdir(data_dir+'/Non_damage_human/')))
print(len(os.listdir(data_dir+'/Non_damage_sea/')))
# Out:
# 1418
# 201
# 36
# 241
# 456
# 4572
# 2271
# 419
# 1035
# 514
# 120
# 2274

# %% [markdown]
# Printing the Names of the Sub-directories

# %%
print(os.listdir(data_dir))
# Out:
# ['DamagedInfrastructure', 'Drought', 'Earthquake', 'Human_Damage', 'Land_Slide', 'Non_Damage_Buildings_Street', 'Non_damage_human', 'Non_damage_sea', 'Non_Damage_Wildlife_Forest', 'Urban_Fire', 'Water_Disaster', 'Wild_Fire']

# %%
classes=os.listdir(data_dir)
classes
# Out:
# ['DamagedInfrastructure',
#  'Drought',
#  'Earthquake',
#  'Human_Damage',
#  'Land_Slide',
#  'Non_Damage_Buildings_Street',
#  'Non_damage_human',
#  'Non_damage_sea',
#  'Non_Damage_Wildlife_Forest',
#  'Urban_Fire',
#  'Water_Disaster',
#  'Wild_Fire']

# %%
source_path=[f'/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/{a}' for a in classes]
print(source_path)
# Out:
# ['/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/DamagedInfrastructure', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Drought', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Earthquake', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Human_Damage', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Land_Slide', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_Damage_Buildings_Street', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_damage_human', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Non_damage_sea', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disas
# ...

# %%
classes_dir=[f'{a}_dir' for a in classes]
classes_dir
# Out:
# ['DamagedInfrastructure_dir',
#  'Drought_dir',
#  'Earthquake_dir',
#  'Human_Damage_dir',
#  'Land_Slide_dir',
#  'Non_Damage_Buildings_Street_dir',
#  'Non_damage_human_dir',
#  'Non_damage_sea_dir',
#  'Non_Damage_Wildlife_Forest_dir',
#  'Urban_Fire_dir',
#  'Water_Disaster_dir',
#  'Wild_Fire_dir']

# %%
for cl_dir,cl_path in zip(classes_dir,source_path):
    print(cl_dir,': ',len(os.listdir(cl_path)))
# Out:
# DamagedInfrastructure_dir :  1418
# Drought_dir :  201
# Earthquake_dir :  36
# Human_Damage_dir :  241
# Land_Slide_dir :  456
# Non_Damage_Buildings_Street_dir :  4572
# Non_damage_human_dir :  120
# Non_damage_sea_dir :  2274
# Non_Damage_Wildlife_Forest_dir :  2271
# Urban_Fire_dir :  419
# Water_Disaster_dir :  1035
# Wild_Fire_dir :  514

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# Making Training and Validation Directories

# %%
try:
    os.mkdir('/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training')
    os.mkdir('/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/validation')
    
except OSError:
    pass

# %%
TRAINING_PATH='/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training'
VALIDATION_PATH='/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/validation'
training_dir_path=[f'/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/{a}' for a in classes]
print('\n',training_dir_path)
validation_dir_path=[f'/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/validation/{a}' for a in classes]
print('\n',validation_dir_path)
# Out:
#  ['/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/DamagedInfrastructure', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Drought', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Earthquake', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Human_Damage', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Land_Slide', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Non_Damage_Buildings_Street', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Non_damage_human', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Non_damage_sea', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Non_Damage_Wildlife_Forest', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Urban_Fire', '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Water_Disaster', '/content/drive/MyDrive/SC
# ...

# %%
for train_dir_path in training_dir_path:
    try:
        os.mkdir(train_dir_path)
    except OSError:
        pass

# %%
for val_dir_path in validation_dir_path:
    try:
        os.mkdir(val_dir_path)
    except OSError:
        pass

# %% [markdown]
# ### Splitting the image data in a 70:30 Ratio

# %%
def split_data(SOURCE, TRAINING, VALIDATION, SPLIT_SIZE):
    files = []
    print('Split Data')
    for filename in os.listdir(SOURCE):
        file = SOURCE +'/'+ filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")

    training_length = int( len(files)* SPLIT_SIZE)
    validation_length = int(len(files) * 0.30)
    
    
    print('SOURCE: ',SOURCE, '\n TRAINING', TRAINING, '\n VALIDATION',VALIDATION, '\n ',len(files))
    print('training_length:',training_length)
    print('validation_length:',validation_length)
   
    
    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    validation_set = shuffled_set[training_length:(training_length+validation_length)]
    

    print(len(training_set))
    print(len(validation_set))
   
    for filename in training_set:
        this_file = SOURCE +'/'+ filename
        destination = TRAINING +'/'+ filename
        copyfile(this_file, destination)
    

    for filename in validation_set:
        this_file = SOURCE +'/'+ filename
        destination = VALIDATION+'/' + filename
        copyfile(this_file, destination)

# %%
split_size = .70
for source,train_dir_path,val_dir_path,in zip(source_path,\
                                training_dir_path,validation_dir_path,):
    #print('source: ',source,'\n', train_dir_path,'\n',val_dir_path,'\n')
    split_data(source,train_dir_path,val_dir_path,split_size)
    print('Splitting \n')
# Out:
# Split Data
# SOURCE:  /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/DamagedInfrastructure
#  TRAINING /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/DamagedInfrastructure
#  VALIDATION /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/validation/DamagedInfrastructure
#   1418
# training_length: 992
# validation_length: 425
# 992
# 425
# Splitting
#
# Split Data
# SOURCE:  /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Drought
#  TRAINING /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training/Drought
#  VALIDATION /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/validation/Drought
#   201
# training_length: 140
# validation_length: 60
# 140
# 60
# Splitting
#
# Split Data
# SOURCE:  /content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/Comprehensive Disaster Dataset(CDD)/Earthquake
# ...

# %% [markdown]
# ## Trying to find out any corrupt images that may be present in the dataset.

# %%
import os
from PIL import Image
folder_path = '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/training'
extensions = []
for fldr in os.listdir(folder_path):
    sub_folder_path = os.path.join(folder_path, fldr)
    for filee in os.listdir(sub_folder_path):
        file_path = os.path.join(sub_folder_path, filee)
        print('** Path: {}  **'.format(file_path), end="\r", flush=True)
        im = Image.open(file_path)
        rgb_im = im.convert('RGB')
        if filee.split('.')[1] not in extensions:
            extensions.append(filee.split('.')[1])

# %%
import os
from PIL import Image
folder_path = '/content/drive/MyDrive/SCAAI_Drive_Akalbir Singh Chadha_PS3/validation'
extensions = []
for fldr in os.listdir(folder_path):
    sub_folder_path = os.path.join(folder_path, fldr)
    for filee in os.listdir(sub_folder_path):
        file_path = os.path.join(sub_folder_path, filee)
        print('** Path: {}  **'.format(file_path), end="\r", flush=True)
        im = Image.open(file_path)
        rgb_im = im.convert('RGB')
        if filee.split('.')[1] not in extensions:
            extensions.append(filee.split('.')[1])
